# %% [markdown]
# <a href="https://colab.research.google.com/github/dornalagopireddy/DATA-SCIENCE/blob/main/Using_Computer_vision_Library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import required libraries
import cv2
import imutils

# %%
#read the orginal image
real=cv2.imread('/peakpx.jpg')

# %%
#convert real to gray image
grayimg=cv2.cvtColor(real,cv2.COLOR_BGR2GRAY)
#CREATE THRESHOLD IMAGE
threshimg=cv2.threshold(grayimg,200,255,cv2.THRESH_BINARY)[1]
canny=cv2.Canny(real,500,75)
#removw the blank spots
dialted=cv2.dilate(canny,(7,7))

# %%
# @title Default title text
#save the converted images
cv2.imwrite("grayimg.jpg",grayimg)
cv2.imwrite("threshimg.jpg",threshimg)
cv2.imwrite("canny.jpg",canny)
# Out:
# True

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(real)
# Out:
# <PIL.Image.Image image mode=RGB size=2160x1440>

# %%
cv2_imshow(grayimg)
# Out:
# <PIL.Image.Image image mode=L size=2160x1440>

# %%
cv2_imshow(canny)
# Out:
# <PIL.Image.Image image mode=L size=2160x1440>

# %%
cv2_imshow(threshimg)
# Out:
# <PIL.Image.Image image mode=L size=2160x1440>

# %%
cv2_imshow(dialted)
# Out:
# <PIL.Image.Image image mode=L size=2160x1440>
